# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pandas import DataFrame
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ## 데이터 concat
# - concat필요하신 분들만 진행해주세요!

# %%
# 날짜 변환 함수 정의
def convert_to_date_only(date_str):
    try:
        # 포맷 없이 변환 시도
        return pd.to_datetime(date_str).date()
    except Exception:
        try:
            # 두 번째 형식 처리: "24.12.06."
            return pd.to_datetime(date_str, format='%y.%m.%d.').date()
        except Exception as e:
            print(f"Error converting {date_str}: {e}")
            return pd.NaT  # 변환 실패 시 NaT 반환

# %%
import pandas as pd
import os
from glob import glob

# 1. 모든 하위 폴더에서 CSV 파일 경로 수집
root_dir = "/content/drive/MyDrive/DIC/포털"
csv_files = glob(os.path.join(root_dir, "**/*.csv"), recursive=True)


# CSV 파일들을 하나의 리스트로 읽기
df_list = []
for file in csv_files:
    data = pd.read_csv(file)
    print(file)
    # 데이터프레임에 변환 적용
    data['date'] = data['date'].apply(convert_to_date_only)
    data = data.dropna(subset=['date'])

    # 기준 날짜로 필터링
    data = data[data['date'] >= pd.to_datetime('2020-01-01').date()].reset_index(drop=True)
    df_list.append(data)

# 모든 필터링된 데이터프레임을 하나로 합치기
df = pd.concat(df_list, axis=0).reset_index(drop=True)

# 결과 확인
print(df.head())
# Out:
# /content/drive/MyDrive/DIC/포털/naver_potal_부모 아이 꽃가루.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_엄마 입학 대청소.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아빠 알러지 먼지_직장인 옷장정리 봄철옷냄새.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_중년 황사 외투먼지제거.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_초딩 미세먼지 봄옷관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_고딩 봄옷살균 얇은재킷관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_독립 점퍼보관 코튼셔츠정리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아줌마 알레르기 환절기.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_노년 통기성 기분전환.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_가족 에어컨냄새 고온.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아빠 땀 얇은옷.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아들 자외선 냉방.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_딸 습기 냄새.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_사회초년 제습 습기제거.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_중딩 장마 기능성.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_고딩 햇볕 린넨.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_노년 비오는날 젖음.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_부모 러닝 홈트.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_독립 메이크업 청결.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_부모 산책 낙엽.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_엄마 피크닉 축제.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_신혼부부 데이트 모닥불.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_취학자녀 명상 장작.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_시니어 단풍놀이 분위기.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_할아버지 가을비 방수.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아기 불멍 간절기.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_부모 패딩 겨울옷.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아빠 목도리 장갑.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_시니어 보온 방한.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_할머니 방한복 눈싸움.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_할아버지 털옷 두꺼운옷관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_자녀결혼 추위 건조.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_1인가구 코트 기분전환.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_자녀 환기 축축.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_중년 눅눅 오염.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_사회초년 강아지 날마다.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_직장인 홈파티 살균.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_사회초년 고양이 꾸준히.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_가족 쇼핑 해피.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_출산 뷰티 깨끗한.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_초딩 뜨개질 산뜻한.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_중딩 스킨케어 찝찝.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_고딩 바비큐 꿉꿉.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_임산부 요가 솔루션.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_할머니 축구 뽀송뽀송.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_할아버지 농구 건강.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_노년 야구 질환.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_동료 기분나쁜 빗물.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아줌마 스타일 입학.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_직장인 정장 수트.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_사회초년 크롭탑 오버핏.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_중년 에코패션 지속가능패션.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_가족 비치웨어 수영복.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_취학자녀 요가복 골프웨어.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_자녀결혼 스키복 방한복.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_엄마 스카프 선글라스.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아빠 백팩 모자.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_부모 원피스 청바지.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아들 티셔츠 후드티.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_딸 블라우스 조거팬츠.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아기 멜빵바지 데님쇼츠.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_신혼부부 파자마(잠옷) 집업후드.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_할머니 브레이슬릿(팔찌) 니트베스트.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_할아버지 선글라스 퍼자켓.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_노년 바이커쇼츠 핀턱팬츠.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_독립 클러치백 스웨트팬츠.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아저씨 모자 작업복.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아줌마 블라우스 출근.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_부모 봄 알러지.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_엄마 봄 꽃가루.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_직장인 봄 냄새.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_사회초년 봄 소개팅코디.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_1인가구 봄 곰팡이.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_중년 봄 재채기.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_초딩 봄 미세먼지.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_가족 여름 에어컨냄새.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아빠 여름 땀.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아들 여름 자외선.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_자녀 여름 냉방.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_중딩 여름 장마.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_고딩 여름 햇볕.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_독립 여름 얇은옷.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_부모 가을 산책.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_엄마 가을 피크닉.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_시니어 가을 단풍놀이.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_신혼부부 가을 간절기.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_할아버지 가을 분위기.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_취학자녀 가을 명상.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아기 가을 불멍.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_부모 겨울 패딩.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아빠 겨울 목도리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_자녀결혼 겨울 추위.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_시니어 겨울 보온.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_할머니 겨울 방한복.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_할아버지 겨울 방한.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_1인가구 겨울 겨울옷.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_직장인 홈트 살균.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_신혼부부 스키 소독.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_사회초년 강아지 기분전환.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_부모 기분좋은 산뜻한.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아들 찝찝 꿉꿉.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_딸 시원 청결.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아기 더워 추워.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_시니어 행복 즐거운.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_1인가구 장갑 머플러.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_독립 메이크업 청결 (3).csv
# /content/drive/MyDrive/DIC/포털/naver_potal_고딩 바비큐 깨끗한 (2).csv
# /content/drive/MyDrive/DIC/포털/naver_potal_부모 기분좋은 산뜻한 (2).csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아들 찝찝 꿉꿉 (2).csv
# /content/drive/MyDrive/DIC/포털/naver_potal_딸 시원 청결 (2).csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아기 더워 추워 (2).csv
# /content/drive/MyDrive/DIC/포털/naver_potal_시니어 행복 즐거운 (2).csv
# /content/drive/MyDrive/DIC/포털/naver_potal_1인가구 장갑 머플러자취생 여름 티셔츠.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_자취생 겨울 패딩.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_자취생 봄 코트.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_자취생 가을 니트.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_혼족 여름 원피스.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_혼족 겨울 스웨터.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_1인가구 겨울 스웨터.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_사회초년생 가을 재킷.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_새내기 겨울 코트.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_신혼부부 여름 원피스.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_캠핑족 여름 반팔티.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_캠핑족 겨울 패딩.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_직장인 여름 셔츠.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_직장인 겨울 코트.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_학생 겨울 패딩.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_학생 여름 반팔티.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_학생 봄 원피스.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_사회초년생 겨울 패딩.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_혼족 가을 원피스.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_혼족 봄 청바지.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_직장인 가을 재킷.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_학생 가을 카디건.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_직장인 봄 정장.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_취준생 여름 셔츠.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_취준생 겨울 코트.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_새내기 봄 셔츠.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_신혼부부 가을 패딩.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_신혼부부 겨울 코트.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_1인가구 여름 반바지.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_1인가구 가을 니트.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_직장인 운동복.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_직장인 출근 셔츠.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_등산객 겨울 패딩.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_등산객 여름 티셔츠.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_캠핑족 가을 재킷.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_캠핑족 봄 재킷.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_운동선수 여름 반바지.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_운동선수 겨울 트레이닝복.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_헬스장 운동복.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_회사원 출근 정장.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_학생 여름 운동복.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_학생 겨울 운동복.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_데이트 여름 원피스.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_데이트 겨울 코트.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_데이트 가을 니트.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_파티 드레스.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_휴가 여름 원피스.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_휴가 겨울 스웨터.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_운동복 냄새.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_운동복 탈취.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_운동복 살균.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_양말 냄새.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_양말 탈취.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_속옷 냄새.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_속옷 살균.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_구두 냄새.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_티셔츠 냄새.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_가디건 냄새.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_니트 냄새.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_원룸 겨울 패딩.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_기숙사 여름 티셔츠.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_원룸 가을 코트.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_기숙사 봄 청바지.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_기숙사 겨울 스웨터.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_트렌치 코트 가을.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_롱 패딩 겨울.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_장마철 블라우스.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_폭염 반팔티.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_혹한 코트.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_환절기 재킷.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_운동회 트레이닝복.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_데이트 봄 원피스.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_자취생 여름 롱 원피스.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_직장인 여름 와이셔츠.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_회식 봄 원피스.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_회식 겨울 코트.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_파티 여름 드레스.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_파티 여름 드레스 (2).csv
# /content/drive/MyDrive/DIC/포털/naver_potal_파티 여름 드레스 (3).csv
# /content/drive/MyDrive/DIC/포털/naver_potal_파티 겨울 코트.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_학생 등교 티셔츠.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_학생 여름 청바지.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_직장인 가을 셔츠.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_직장인 봄 스커트.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_직장인 가을 블라우스.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_새내기 가을 청바지.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_새내기 봄 스니커즈.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_1인가구 봄 원피스.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_1인가구 겨울 니트.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_혼족 가을 카디건.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_캠핑족 봄 티셔츠.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_등산객 가을 바지.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_등산객 가을 스웨터.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_운동선수 가을 트레이닝복.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_헬스장 여름 반팔티.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_헬스장 겨울 스웨터.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_여행객 여름 반바지.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_여행객 겨울 코트.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_휴가 여름 스커트.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_휴가 가을 스웨터.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_혼족 가을 청바지.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_1인가구 봄 셔츠.csv
# /content/drive/MyDrive/DIC/포털/blog_crawling_result_블로그2.csv
# /content/drive/MyDrive/DIC/포털/blog_crawling_result_블로그3.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_기숙사 여름 셔츠.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_오피스텔 간절기 재킷.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_원룸 봄 코디.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_독립 가을 블라우스.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_혼자사는 남자 겨울 코트.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_독립 초년생 봄 셔츠.csv
# /content/drive/MyDrive/DIC/포털/blog_crawling_result_블로그4.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_고딩 바비큐 깨끗한.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_독립 메이크업 청결 (2).csv
# /content/drive/MyDrive/DIC/포털/naver_potal_사회초년 소개팅코디 재채기.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_1인가구 콧물 곰팡이.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_.아빠 알러지 먼지.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_가정용 제습법.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_습기 제거 천연법.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_장마 빨래 악취.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_알레르기 빨래법.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_환절기 빨래 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_천연 섬유 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_옷 곰팡이 예방.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_황사 옷 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_장마철 옷 관리법.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_옷 냄새 천연 제거.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_장마철 빨래 팁.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_건강 옷관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_실내 먼지 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_실내 빨래 습기.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_건조기 대안 방법.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_섬유유연제 부작용.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_알레르기 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_건강 세탁법.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_천연 탈취제.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_겨울옷 습기 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_가족용 탈취제.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_실내 알레르기 예방.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아이 이불 관리법.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_집안 공기청정.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_육아 세탁법.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아이 옷장 정리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아이 등교 준비.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_장마철 아이 옷.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_학교 가방 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아이 체육복 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아이 옷 냄새 제거.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아이 방 습기제거.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_집안 먼지 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_유아 옷 건조법.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아이 교복 얼룩.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_가족 옷냄새 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아이 겨울옷 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아이 알레르기 예방.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_육아 빨래 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_가족 옷장 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_직장인 미세먼지.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_겨울옷 보관팁.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_자켓 깔끔 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_깔끔한 정장 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_장마철 출근룩 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_재킷 냄새 제거.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_결혼 준비 옷정리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_침실 옷장 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_스타일 관리 팁.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_실내 먼지 제거법.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_신혼집 옷정리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_옷 냄새 빠르게 제거.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아파트 습기 방지.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_깔끔한 옷장 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_직장인 출근룩.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_출근 전 셔츠 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_정장 주름 방지.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_결혼 전 옷 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_옷방 인테리어.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_집안 습기 제거.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_자취생 습기제거.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_셔츠 깔끔 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_비오는 날 자취방.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_외출 전 옷 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_혼자살이 빨래 건조.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_혼자 사는 빨래 팁.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_소개팅 코디법.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_알러지 방지 팁.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_패션 관리법.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_첫 데이트 코디.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_옷냄새 제거법.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_블라우스 주름 방지.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_면접 옷 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_체육복 건조법.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_자취 빨래 냄새.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_원룸 습기 제거.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_미세먼지 옷 보호.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_청소년 니트 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_학생용 세탁팁.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_옷장 제습 방법.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_미세먼지 피부트러블.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_학교 셔츠 관리법.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_장마철 등교복.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_체육복 세탁.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_자켓 보관법.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_운동복 관리법.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_시험기간 옷정리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_실내 먼지 알레르기.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_학생용 탈취제.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_학원 옷관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_취준생 정장 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_학교 옷 냄새.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_크리에이터 데일리룩.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_프리랜서 홈웨어 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_디자이너 니트 정리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_인플루언서 촬영 전 셔츠.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_방송인 옷장 정리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_알레르기 방지.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_청소년 피부관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_운동복 매일 세탁.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_직장인 데일리 블라우스.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_오피스룩 주름 걱정.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_집들이 준비 셔츠.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_장거리 출근 옷 주름.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_소개팅 날 셔츠 구김.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_사회초년생 겨울 셔츠.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_캠핑 후 옷 냄새.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_새내기 옷 보관.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_여행 후 옷 정리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_매일 세탁 힘든 직장인.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_살균 중시 직장인 코디.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_헬스장 운동복 세탁.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_위생에 민감한 남자 셔츠.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_옷장 정리 스트레스.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_출근 전 코디 정리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_잦은 출장 옷 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_회식 다음날 옷 냄새.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_미니멀리스트 봄 패션.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_외출 잦은 여름 셔츠.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_패딩 곰팡이 방지.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_냄새 나는 옷장.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_축축한 옷 말리기.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_장마철 의류 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_땀 많이 나는 옷.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_여름 땀 냄새.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_운동복 냄새 제거.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_꿉꿉한 옷 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_봄철 옷 냄새.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_비오는 날 옷 정리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_혼족 봄 수트 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_간절기 점퍼 보관법.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_여름 린넨 셔츠 냄새.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_겨울 니트 먼지.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_아우터 냄새 제거.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_여름 흰 셔츠 관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_여름 얇은 옷 정리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_트렌치코트 관리법.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_봄 코트 보풀.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_겨울 롱패딩 정리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_자취방 겨울 니트.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_1인가구 여름 이불관리.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_신혼부부 봄 아우터.csv
# /content/drive/MyDrive/DIC/포털/naver_potal_할머니 봄비 피부.csv
# <ipython-input-4-b652ec6b0756>:24: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(df_list, axis=0).reset_index(drop=True)
#    Unnamed: 0        date                                            keyword  \
# 0         0.0  2022-04-10  ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# 1         1.0  2021-05-09  ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# 2         2.0  2025-04-14  ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# 3         3.0  2021-04-18  ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# 4         4.0  2024-04-19  ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
#
#                                          title  \
# 0  꽃가루 알러지 없는 부모님은 모르는 아이의 꽃가루 알러지... 시작되었습니다.
# 1                    꽃가루 알러지 있는 자녀 두신 부모님 보세요~
# 2            부산 유아 아토피, 한의학에서 바라보는 원인과 증상에 대하여
# 3                  꽃가루 알러지 있으신 자녀 키우시는 분들 보세요~
# 4                                어린이 운동회에 참여하다
#
#                                             contents  \
# 0  (이 글을 봄마다 쓰는 이유는) 제목 그대로 입니다. 꽃가루 알러지를 겪어보지 못한...
# 1  네이버 꽃가루 지수 검색하면 꽃가루 소나무(노란 송홧가루)가 대구에 <보통>으로 뜨...
# 2  안녕하세요. 가려움에 밤잠 못 이루는 우리 아이,어떻게 도와줘야 할까요? 밤마다 몸...
# 3  학기초만 되면 (보통 중간고사 기간부터 스승의날까지) 미열에 목 아프고, 피부도 가...
# 4  이제 겨울이 가고 봄이 찾아왔다. 봄이란 무엇인가?봄은 본디 생명, 꽃, 따스함의 ...
#
#                                             comments   site  \
# 0  ['주말 마무리 잘해요~^^', '^^', '저희애들도작년에꽃가루로 고생했던지라, ...  네이버포탈
# 1  ['안그래도 꽃가루 언제 끝나는지 궁금했는데 이렇게 검색할수있군요 ㅎㅎ 정보 감사해...  네이버포탈
# 2  ['아토피에 대한 원인과 증상이 이렇게 자세히 설명되어 있어서 좋네요. 아이에게 꼭...  네이버포탈
# 3  ['저희아이가 그래요;;봄마다  얼굴붓고 눈붓고 가렵고...지금도 비염이 심해서져서...  네이버포탈
# 4                            ['어른도 아이도 귀엽네', '귀엽내~']  네이버포탈
#
#                                                  url content
# 0  https://cafe.naver.com/dgmom365/5796590?art=ZX...     NaN
# 1  https://cafe.naver.com/dgmom365/5261698?art=ZX...     NaN
# 2  https://cafe.naver.com/dnfdot/12668?art=ZXh0ZX...     NaN
# 3  https://cafe.naver.com/dgmom365/5227805?art=ZX...     NaN
# 4  https://cafe.naver.com/ganada0811/46463?art=ZX...     NaN

# %%
df.to_csv("/content/drive/MyDrive/DataSet/filtered_2020_2025_portal.csv", index=False, encoding='utf-8-sig')

# %%
import pandas as pd

keyword = ['키워드1', '키워드2', '키워드3', '키워드4', '키워드5']
data_list = []  # 데이터를 임시로 저장할 리스트

# 각 키워드에 해당하는 데이터를 불러와서 리스트에 추가
for i in keyword:
    data = pd.read_csv(f"네이버포털_카테고리분류명_이름_{i}.csv")
    data_list.append(data)

# 리스트를 한 번에 합치기
df = pd.concat(data_list, axis=0).reset_index(drop=True)

df

# %% [markdown]
# ## 데이터 통합본 불러오기
# - 통합본이 따로 있는 경우!

# %%
df1 = pd.read_csv("네이버포털_공간_다운_추가.csv")
df2 = pd.read_csv("네이버포털_공간_다운_통합.csv")
df = pd.concat([df1, df2], axis =0)
print(df.shape)
df.head()

# %% [markdown]
# ## 중복제거

# %%
# 중복 제거 및 인덱스 초기화
df = df.drop_duplicates(subset=['date', 'title', 'contents', 'comments'], keep='first', inplace=False)
df = df.reset_index(drop=True)

# 중복 제거 후 데이터프레임 길이 출력
df.head()
# Out:
#    Unnamed: 0        date                                            keyword  \
# 0         0.0  2022-04-10  ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# 1         1.0  2021-05-09  ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# 2         2.0  2025-04-14  ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# 3         3.0  2021-04-18  ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# 4         4.0  2024-04-19  ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
#
#                                          title  \
# 0  꽃가루 알러지 없는 부모님은 모르는 아이의 꽃가루 알러지... 시작되었습니다.
# 1                    꽃가루 알러지 있는 자녀 두신 부모님 보세요~
# 2            부산 유아 아토피, 한의학에서 바라보는 원인과 증상에 대하여
# 3                  꽃가루 알러지 있으신 자녀 키우시는 분들 보세요~
# 4                                어린이 운동회에 참여하다
#
#                                             contents  \
# 0  (이 글을 봄마다 쓰는 이유는) 제목 그대로 입니다. 꽃가루 알러지를 겪어보지 못한...
# 1  네이버 꽃가루 지수 검색하면 꽃가루 소나무(노란 송홧가루)가 대구에 <보통>으로 뜨...
# 2  안녕하세요. 가려움에 밤잠 못 이루는 우리 아이,어떻게 도와줘야 할까요? 밤마다 몸...
# 3  학기초만 되면 (보통 중간고사 기간부터 스승의날까지) 미열에 목 아프고, 피부도 가...
# 4  이제 겨울이 가고 봄이 찾아왔다. 봄이란 무엇인가?봄은 본디 생명, 꽃, 따스함의 ...
#
#                                             comments   site  \
# 0  ['주말 마무리 잘해요~^^', '^^', '저희애들도작년에꽃가루로 고생했던지라, ...  네이버포탈
# 1  ['안그래도 꽃가루 언제 끝나는지 궁금했는데 이렇게 검색할수있군요 ㅎㅎ 정보 감사해...  네이버포탈
# 2  ['아토피에 대한 원인과 증상이 이렇게 자세히 설명되어 있어서 좋네요. 아이에게 꼭...  네이버포탈
# 3  ['저희아이가 그래요;;봄마다  얼굴붓고 눈붓고 가렵고...지금도 비염이 심해서져서...  네이버포탈
# 4                            ['어른도 아이도 귀엽네', '귀엽내~']  네이버포탈
#
#                                                  url content
# 0  https://cafe.naver.com/dgmom365/5796590?art=ZX...     NaN
# 1  https://cafe.naver.com/dgmom365/5261698?art=ZX...     NaN
# 2  https://cafe.naver.com/dnfdot/12668?art=ZXh0ZX...     NaN
# 3  https://cafe.naver.com/dgmom365/5227805?art=ZX...     NaN
# 4  https://cafe.naver.com/ganada0811/46463?art=ZX...     NaN

# %%
df.shape
# Out:
# (55207, 9)

# %% [markdown]
# ## 날짜 기준 필터링

# %%
# 날짜 변환 함수 정의
def convert_to_date_only(date_str):
    try:
        # 포맷 없이 변환 시도
        return pd.to_datetime(date_str).date()
    except Exception:
        try:
            # 두 번째 형식 처리: "24.12.06."
            return pd.to_datetime(date_str, format='%y.%m.%d.').date()
        except Exception as e:
            print(f"Error converting {date_str}: {e}")
            return pd.NaT  # 변환 실패 시 NaT 반환

# 데이터프레임에 변환 적용
df['date'] = df['date'].apply(convert_to_date_only)

# NaT 값 확인
print("변환 실패한 데이터:")
print(df[df['date'].isna()])

# 유효한 데이터만 남기기
df = df.dropna(subset=['date'])

# 기준 날짜로 필터링
df = df[df['date'] >= pd.to_datetime('2020-01-01').date()].reset_index(drop=True)

# 결과 확인
df

# %% [markdown]
# ## \n 제거

# %%
def preprocess_text(text):
    if isinstance(text, str):
        text = re.sub(r'<[^>]+>', '', text)
        text = re.sub(r'\n', ' ', text)
        text = re.sub(r'\s+', ' ', text)

    return text

df['title'] = df['title'].apply(preprocess_text)
df['contents'] = df['contents'].apply(preprocess_text)
df['comments'] = df['comments'].apply(preprocess_text)
df['date'] = df['date'].apply(preprocess_text)

# %% [markdown]
# ## 제목에서 광고글 제거

# %%
df1 = df.copy()

words_to_delete = ['협찬', '체험단', '무료체험', '예약링크', '홍보','무료제공','무상제공','위스토어', '출석체크','체험단','긴급','가입인사','모집','양도매매',]

pattern = '|'.join(words_to_delete)

delete = df1['title'].str.contains(pattern)

# %%
#삭제할 행 확인
df1['title'][df1.index[delete]]
# Out:
# 1626                                  [가디언] 숲스러운 사이 서평단 모집
# 2314                        (완료)🌻꽃맘 옷장 97호 후기 및 98호 주자 모집🌻
# 3372                                [이담북스] 지구인의 반성문 서평단 모집
# 3581     [SUIBOM] SUIBOM EARTH LOGO SWEATSHIRTS - BLACK...
# 3692     결혼하자 맹꽁아 8회 양미경 파란 남방 의상 협찬 블루 자수 셔츠 코디♥맹공희 엄마...
#                                ...
# 54237                            남은 생은 쫌 다르게 입기로 했다 4기 모집
# 54398      [퍼퓸드말리] 첫 방문형 체험단 다녀 온 후기 - 신제품 발라야 익스클루시브 시향기
# 54647         그레이 그라운드 Scent of Province 생폴드방스 향수 체험단 후기!
# 54687      [드로우핏] 오픈카라 티셔츠(TURQUOISE BLUE) 티셔츠 ㅈ문가 체험단 후기
# 55162     [체험단 후기] [응답하라아지매/지방출장] 무료체험단 마이팜 “지방출장”으로 지방...
# Name: title, Length: 163, dtype: object

# %%
df1.drop(df1[delete].index, inplace = True)
df2= df1.reset_index(drop=True)
df2
# Out:
#        Unnamed: 0        date  \
# 0             0.0  2022-04-10
# 1             1.0  2021-05-09
# 2             2.0  2025-04-14
# 3             3.0  2021-04-18
# 4             4.0  2024-04-19
# ...           ...         ...
# 55039     15554.0  2021-07-04
# 55040     15555.0  2021-10-24
# 55041     15560.0  2020-12-11
# 55042     15569.0  2020-12-04
# 55043     15575.0  2022-05-17
#
#                                                  keyword  \
# 0      ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# 1      ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# 2      ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# 3      ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# 4      ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# ...                                                  ...
# 55039  ['옷장 정리 스트레스+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수...
# 55040  ['옷장 정리 스트레스+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수...
# 55041  ['옷장 정리 스트레스+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수...
# 55042  ['옷장 정리 스트레스+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수...
# 55043  ['옷장 정리 스트레스+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수...
#
#                                              title  \
# 0      꽃가루 알러지 없는 부모님은 모르는 아이의 꽃가루 알러지... 시작되었습니다.
# 1                        꽃가루 알러지 있는 자녀 두신 부모님 보세요~
# 2                부산 유아 아토피, 한의학에서 바라보는 원인과 증상에 대하여
# 3                      꽃가루 알러지 있으신 자녀 키우시는 분들 보세요~
# 4                                    어린이 운동회에 참여하다
# ...                                            ...
# 55039                 함께 못 사는 나라로 가고 있다 ~165페이지~끝
# 55040      [커버스토리] 나는 단순하게 살기로 했다…미니멀 라이프 실천하는 그들
# 55041                         7. 꿈깨라 이년아 79 최서방 첩
# 55042                       (강서양천점) 현숙 이모님 감사합니다~
# 55043                           인도네시아 /나무위키 (2/2)
#
#                                                 contents  \
# 0      (이 글을 봄마다 쓰는 이유는) 제목 그대로 입니다. 꽃가루 알러지를 겪어보지 못한...
# 1      네이버 꽃가루 지수 검색하면 꽃가루 소나무(노란 송홧가루)가 대구에 으로 뜨기 시작...
# 2      안녕하세요. 가려움에 밤잠 못 이루는 우리 아이,어떻게 도와줘야 할까요? 밤마다 몸...
# 3      학기초만 되면 (보통 중간고사 기간부터 스승의날까지) 미열에 목 아프고, 피부도 가...
# 4      이제 겨울이 가고 봄이 찾아왔다. 봄이란 무엇인가?봄은 본디 생명, 꽃, 따스함의 ...
# ...                                                  ...
# 55039  제9장 불균형 해소, 바른 해법을 제시한다· ·····················...
# 55040  봄을 기다리는 지금, 새로운 결심을 하기 좋은 때다. 요즘은 ‘비우고 단순해지기’를...
# 55041  남자가외도하는이유 바람난아내잡는법! 유용한 정보! 번역하기남자가외도하는이유 바람난아...
# 55042  졔가 둘째 산후조리업체를 닥터맘을 선택한 이유는 5년 전 첫째 산후조리할 때도 닥터...
# 55043  9. 정치자세한 내용은 인도네시아/정치 문서를 참고하십시오.10. 군사자세한 내용은...
#
#                                                 comments   site  \
# 0      ['주말 마무리 잘해요~^^', '^^', '저희애들도작년에꽃가루로 고생했던지라, ...  네이버포탈
# 1      ['안그래도 꽃가루 언제 끝나는지 궁금했는데 이렇게 검색할수있군요 ㅎㅎ 정보 감사해...  네이버포탈
# 2      ['아토피에 대한 원인과 증상이 이렇게 자세히 설명되어 있어서 좋네요. 아이에게 꼭...  네이버포탈
# 3      ['저희아이가 그래요;;봄마다 얼굴붓고 눈붓고 가렵고...지금도 비염이 심해서져서 ...  네이버포탈
# 4                                ['어른도 아이도 귀엽네', '귀엽내~']  네이버포탈
# ...                                                  ...    ...
# 55039                                                 []  네이버포탈
# 55040                                                 []  네이버포탈
# 55041                                                 []  네이버포탈
# 55042                                                 []  네이버포탈
# 55043                                                 []  네이버포탈
#
#                                                      url content
# 0      https://cafe.naver.com/dgmom365/5796590?art=ZX...     NaN
# 1      https://cafe.naver.com/dgmom365/5261698?art=ZX...     NaN
# 2      https://cafe.naver.com/dnfdot/12668?art=ZXh0ZX...     NaN
# 3      https://cafe.naver.com/dgmom365/5227805?art=ZX...     NaN
# 4      https://cafe.naver.com/ganada0811/46463?art=ZX...     NaN
# ...                                                  ...     ...
# 55039  https://cafe.naver.com/gagebuband/429?art=ZXh0...     NaN
# 55040  https://cafe.naver.com/tongkn/4321?art=ZXh0ZXJ...     NaN
# 55041  https://cafe.naver.com/greenb0k6k/25699?art=ZX...     NaN
# 55042  https://cafe.naver.com/mamtalks/3013?art=ZXh0Z...     NaN
# 55043  https://cafe.naver.com/jsseo43/18879?art=ZXh0Z...     NaN
#
# [55044 rows x 9 columns]

# %% [markdown]
# ## 10글자 미만 댓글 제거

# %%
# 댓글 리스트에서 10글자 미만의 요소를 제거하는 함수
def filter_short_comments(comment_list):
    # 리스트인지 확인 후 각 요소의 길이를 확인해 10글자 이상인 요소만 남김
    if isinstance(comment_list, list):
        return [comment for comment in comment_list if len(comment) >= 10]
    return comment_list  # 리스트가 아니면 그대로 반환

# DataFrame의 comments 열에 적용
df2['comments'] = df2['comments'].apply(filter_short_comments)

# comments 열이 빈 리스트인 행 제거
df2['comments'] = df2['comments'].apply(lambda x: '댓글 없음' if isinstance(x, list) and len(x) == 0 else ' '.join(x) if isinstance(x, list) else str(x))

df2
# Out:
#        Unnamed: 0        date  \
# 0             0.0  2022-04-10
# 1             1.0  2021-05-09
# 2             2.0  2025-04-14
# 3             3.0  2021-04-18
# 4             4.0  2024-04-19
# ...           ...         ...
# 55039     15554.0  2021-07-04
# 55040     15555.0  2021-10-24
# 55041     15560.0  2020-12-11
# 55042     15569.0  2020-12-04
# 55043     15575.0  2022-05-17
#
#                                                  keyword  \
# 0      ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# 1      ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# 2      ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# 3      ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# 4      ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# ...                                                  ...
# 55039  ['옷장 정리 스트레스+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수...
# 55040  ['옷장 정리 스트레스+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수...
# 55041  ['옷장 정리 스트레스+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수...
# 55042  ['옷장 정리 스트레스+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수...
# 55043  ['옷장 정리 스트레스+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수...
#
#                                              title  \
# 0      꽃가루 알러지 없는 부모님은 모르는 아이의 꽃가루 알러지... 시작되었습니다.
# 1                        꽃가루 알러지 있는 자녀 두신 부모님 보세요~
# 2                부산 유아 아토피, 한의학에서 바라보는 원인과 증상에 대하여
# 3                      꽃가루 알러지 있으신 자녀 키우시는 분들 보세요~
# 4                                    어린이 운동회에 참여하다
# ...                                            ...
# 55039                 함께 못 사는 나라로 가고 있다 ~165페이지~끝
# 55040      [커버스토리] 나는 단순하게 살기로 했다…미니멀 라이프 실천하는 그들
# 55041                         7. 꿈깨라 이년아 79 최서방 첩
# 55042                       (강서양천점) 현숙 이모님 감사합니다~
# 55043                           인도네시아 /나무위키 (2/2)
#
#                                                 contents  \
# 0      (이 글을 봄마다 쓰는 이유는) 제목 그대로 입니다. 꽃가루 알러지를 겪어보지 못한...
# 1      네이버 꽃가루 지수 검색하면 꽃가루 소나무(노란 송홧가루)가 대구에 으로 뜨기 시작...
# 2      안녕하세요. 가려움에 밤잠 못 이루는 우리 아이,어떻게 도와줘야 할까요? 밤마다 몸...
# 3      학기초만 되면 (보통 중간고사 기간부터 스승의날까지) 미열에 목 아프고, 피부도 가...
# 4      이제 겨울이 가고 봄이 찾아왔다. 봄이란 무엇인가?봄은 본디 생명, 꽃, 따스함의 ...
# ...                                                  ...
# 55039  제9장 불균형 해소, 바른 해법을 제시한다· ·····················...
# 55040  봄을 기다리는 지금, 새로운 결심을 하기 좋은 때다. 요즘은 ‘비우고 단순해지기’를...
# 55041  남자가외도하는이유 바람난아내잡는법! 유용한 정보! 번역하기남자가외도하는이유 바람난아...
# 55042  졔가 둘째 산후조리업체를 닥터맘을 선택한 이유는 5년 전 첫째 산후조리할 때도 닥터...
# 55043  9. 정치자세한 내용은 인도네시아/정치 문서를 참고하십시오.10. 군사자세한 내용은...
#
#                                                 comments   site  \
# 0      ['주말 마무리 잘해요~^^', '^^', '저희애들도작년에꽃가루로 고생했던지라, ...  네이버포탈
# 1      ['안그래도 꽃가루 언제 끝나는지 궁금했는데 이렇게 검색할수있군요 ㅎㅎ 정보 감사해...  네이버포탈
# 2      ['아토피에 대한 원인과 증상이 이렇게 자세히 설명되어 있어서 좋네요. 아이에게 꼭...  네이버포탈
# 3      ['저희아이가 그래요;;봄마다 얼굴붓고 눈붓고 가렵고...지금도 비염이 심해서져서 ...  네이버포탈
# 4                                ['어른도 아이도 귀엽네', '귀엽내~']  네이버포탈
# ...                                                  ...    ...
# 55039                                                 []  네이버포탈
# 55040                                                 []  네이버포탈
# 55041                                                 []  네이버포탈
# 55042                                                 []  네이버포탈
# 55043                                                 []  네이버포탈
#
#                                                      url content
# 0      https://cafe.naver.com/dgmom365/5796590?art=ZX...     NaN
# 1      https://cafe.naver.com/dgmom365/5261698?art=ZX...     NaN
# 2      https://cafe.naver.com/dnfdot/12668?art=ZXh0ZX...     NaN
# 3      https://cafe.naver.com/dgmom365/5227805?art=ZX...     NaN
# 4      https://cafe.naver.com/ganada0811/46463?art=ZX...     NaN
# ...                                                  ...     ...
# 55039  https://cafe.naver.com/gagebuband/429?art=ZXh0...     NaN
# 55040  https://cafe.naver.com/tongkn/4321?art=ZXh0ZXJ...     NaN
# 55041  https://cafe.naver.com/greenb0k6k/25699?art=ZX...     NaN
# 55042  https://cafe.naver.com/mamtalks/3013?art=ZXh0Z...     NaN
# 55043  https://cafe.naver.com/jsseo43/18879?art=ZXh0Z...     NaN
#
# [55044 rows x 9 columns]

# %% [markdown]
# ## 본문 10글자 미만 제거

# %%
# 10글자 미만인 행 제거
df2 = df2[df2['contents'].str.len() >= 10]

# 결과 출력
df2
# Out:
#        Unnamed: 0        date  \
# 0             0.0  2022-04-10
# 1             1.0  2021-05-09
# 2             2.0  2025-04-14
# 3             3.0  2021-04-18
# 4             4.0  2024-04-19
# ...           ...         ...
# 55039     15554.0  2021-07-04
# 55040     15555.0  2021-10-24
# 55041     15560.0  2020-12-11
# 55042     15569.0  2020-12-04
# 55043     15575.0  2022-05-17
#
#                                                  keyword  \
# 0      ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# 1      ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# 2      ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# 3      ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# 4      ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# ...                                                  ...
# 55039  ['옷장 정리 스트레스+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수...
# 55040  ['옷장 정리 스트레스+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수...
# 55041  ['옷장 정리 스트레스+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수...
# 55042  ['옷장 정리 스트레스+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수...
# 55043  ['옷장 정리 스트레스+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수...
#
#                                              title  \
# 0      꽃가루 알러지 없는 부모님은 모르는 아이의 꽃가루 알러지... 시작되었습니다.
# 1                        꽃가루 알러지 있는 자녀 두신 부모님 보세요~
# 2                부산 유아 아토피, 한의학에서 바라보는 원인과 증상에 대하여
# 3                      꽃가루 알러지 있으신 자녀 키우시는 분들 보세요~
# 4                                    어린이 운동회에 참여하다
# ...                                            ...
# 55039                 함께 못 사는 나라로 가고 있다 ~165페이지~끝
# 55040      [커버스토리] 나는 단순하게 살기로 했다…미니멀 라이프 실천하는 그들
# 55041                         7. 꿈깨라 이년아 79 최서방 첩
# 55042                       (강서양천점) 현숙 이모님 감사합니다~
# 55043                           인도네시아 /나무위키 (2/2)
#
#                                                 contents  \
# 0      (이 글을 봄마다 쓰는 이유는) 제목 그대로 입니다. 꽃가루 알러지를 겪어보지 못한...
# 1      네이버 꽃가루 지수 검색하면 꽃가루 소나무(노란 송홧가루)가 대구에 으로 뜨기 시작...
# 2      안녕하세요. 가려움에 밤잠 못 이루는 우리 아이,어떻게 도와줘야 할까요? 밤마다 몸...
# 3      학기초만 되면 (보통 중간고사 기간부터 스승의날까지) 미열에 목 아프고, 피부도 가...
# 4      이제 겨울이 가고 봄이 찾아왔다. 봄이란 무엇인가?봄은 본디 생명, 꽃, 따스함의 ...
# ...                                                  ...
# 55039  제9장 불균형 해소, 바른 해법을 제시한다· ·····················...
# 55040  봄을 기다리는 지금, 새로운 결심을 하기 좋은 때다. 요즘은 ‘비우고 단순해지기’를...
# 55041  남자가외도하는이유 바람난아내잡는법! 유용한 정보! 번역하기남자가외도하는이유 바람난아...
# 55042  졔가 둘째 산후조리업체를 닥터맘을 선택한 이유는 5년 전 첫째 산후조리할 때도 닥터...
# 55043  9. 정치자세한 내용은 인도네시아/정치 문서를 참고하십시오.10. 군사자세한 내용은...
#
#                                                 comments   site  \
# 0      ['주말 마무리 잘해요~^^', '^^', '저희애들도작년에꽃가루로 고생했던지라, ...  네이버포탈
# 1      ['안그래도 꽃가루 언제 끝나는지 궁금했는데 이렇게 검색할수있군요 ㅎㅎ 정보 감사해...  네이버포탈
# 2      ['아토피에 대한 원인과 증상이 이렇게 자세히 설명되어 있어서 좋네요. 아이에게 꼭...  네이버포탈
# 3      ['저희아이가 그래요;;봄마다 얼굴붓고 눈붓고 가렵고...지금도 비염이 심해서져서 ...  네이버포탈
# 4                                ['어른도 아이도 귀엽네', '귀엽내~']  네이버포탈
# ...                                                  ...    ...
# 55039                                                 []  네이버포탈
# 55040                                                 []  네이버포탈
# 55041                                                 []  네이버포탈
# 55042                                                 []  네이버포탈
# 55043                                                 []  네이버포탈
#
#                                                      url content
# 0      https://cafe.naver.com/dgmom365/5796590?art=ZX...     NaN
# 1      https://cafe.naver.com/dgmom365/5261698?art=ZX...     NaN
# 2      https://cafe.naver.com/dnfdot/12668?art=ZXh0ZX...     NaN
# 3      https://cafe.naver.com/dgmom365/5227805?art=ZX...     NaN
# 4      https://cafe.naver.com/ganada0811/46463?art=ZX...     NaN
# ...                                                  ...     ...
# 55039  https://cafe.naver.com/gagebuband/429?art=ZXh0...     NaN
# 55040  https://cafe.naver.com/tongkn/4321?art=ZXh0ZXJ...     NaN
# 55041  https://cafe.naver.com/greenb0k6k/25699?art=ZX...     NaN
# 55042  https://cafe.naver.com/mamtalks/3013?art=ZXh0Z...     NaN
# 55043  https://cafe.naver.com/jsseo43/18879?art=ZXh0Z...     NaN
#
# [55012 rows x 9 columns]

# %%
df3 = df2.copy()

# %%
df3['contents'] = df3['contents'].str.replace(r'\[이미지[^\]]*\]', '', regex=True)
df3['contents'] = df['contents'].str.replace(r'\s+', ' ', regex=True)

df3['comments'] = df3['comments'].str.replace(r'\[이미지[^\]]*\]', '', regex=True)
df3['comments'] = df3['comments'].str.replace(r'\s+', ' ', regex=True)
# 결과 확인
df3
# Out:
#        Unnamed: 0        date  \
# 0             0.0  2022-04-10
# 1             1.0  2021-05-09
# 2             2.0  2025-04-14
# 3             3.0  2021-04-18
# 4             4.0  2024-04-19
# ...           ...         ...
# 55039     15554.0  2021-07-04
# 55040     15555.0  2021-10-24
# 55041     15560.0  2020-12-11
# 55042     15569.0  2020-12-04
# 55043     15575.0  2022-05-17
#
#                                                  keyword  \
# 0      ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# 1      ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# 2      ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# 3      ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# 4      ['부모 아이 꽃가루+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수료...
# ...                                                  ...
# 55039  ['옷장 정리 스트레스+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수...
# 55040  ['옷장 정리 스트레스+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수...
# 55041  ['옷장 정리 스트레스+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수...
# 55042  ['옷장 정리 스트레스+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수...
# 55043  ['옷장 정리 스트레스+%2B옷 -광고 -홍보 -할인 -핫딜 -특가 -이벤트 -수수...
#
#                                              title  \
# 0      꽃가루 알러지 없는 부모님은 모르는 아이의 꽃가루 알러지... 시작되었습니다.
# 1                        꽃가루 알러지 있는 자녀 두신 부모님 보세요~
# 2                부산 유아 아토피, 한의학에서 바라보는 원인과 증상에 대하여
# 3                      꽃가루 알러지 있으신 자녀 키우시는 분들 보세요~
# 4                                    어린이 운동회에 참여하다
# ...                                            ...
# 55039                 함께 못 사는 나라로 가고 있다 ~165페이지~끝
# 55040      [커버스토리] 나는 단순하게 살기로 했다…미니멀 라이프 실천하는 그들
# 55041                         7. 꿈깨라 이년아 79 최서방 첩
# 55042                       (강서양천점) 현숙 이모님 감사합니다~
# 55043                           인도네시아 /나무위키 (2/2)
#
#                                                 contents  \
# 0      (이 글을 봄마다 쓰는 이유는) 제목 그대로 입니다. 꽃가루 알러지를 겪어보지 못한...
# 1      네이버 꽃가루 지수 검색하면 꽃가루 소나무(노란 송홧가루)가 대구에 으로 뜨기 시작...
# 2      안녕하세요. 가려움에 밤잠 못 이루는 우리 아이,어떻게 도와줘야 할까요? 밤마다 몸...
# 3      학기초만 되면 (보통 중간고사 기간부터 스승의날까지) 미열에 목 아프고, 피부도 가...
# 4      이제 겨울이 가고 봄이 찾아왔다. 봄이란 무엇인가?봄은 본디 생명, 꽃, 따스함의 ...
# ...                                                  ...
# 55039  세상에서 옷장정리가가장 어려운 것 같아요ㅠ 이제 곧 이사 가야 하는데,이번엔 정말 ...
# 55040  첨부파일 산책_240219.pdf null 파일 다운로드 내 컴퓨터 저장 네이버 M...
# 55041  우선 진짜 감사하다는 말.꼭 하고 싶습니다. 솔직히 엄청 혼날 줄 알았는데 응원해주...
# 55042   S#1 1950년 6월 23일 금요일(저녁 7시) 서울 석구집(1950년 6월 2...
# 55043   S#1 서울 석구집, 전경 (밤)S#2 석구집, 방안 (밤)S#3 기차 안 (낮)...
#
#                                                 comments   site  \
# 0      ['주말 마무리 잘해요~^^', '^^', '저희애들도작년에꽃가루로 고생했던지라, ...  네이버포탈
# 1      ['안그래도 꽃가루 언제 끝나는지 궁금했는데 이렇게 검색할수있군요 ㅎㅎ 정보 감사해...  네이버포탈
# 2      ['아토피에 대한 원인과 증상이 이렇게 자세히 설명되어 있어서 좋네요. 아이에게 꼭...  네이버포탈
# 3      ['저희아이가 그래요;;봄마다 얼굴붓고 눈붓고 가렵고...지금도 비염이 심해서져서 ...  네이버포탈
# 4                                ['어른도 아이도 귀엽네', '귀엽내~']  네이버포탈
# ...                                                  ...    ...
# 55039                                                 []  네이버포탈
# 55040                                                 []  네이버포탈
# 55041                                                 []  네이버포탈
# 55042                                                 []  네이버포탈
# 55043                                                 []  네이버포탈
#
#                                                      url content
# 0      https://cafe.naver.com/dgmom365/5796590?art=ZX...     NaN
# 1      https://cafe.naver.com/dgmom365/5261698?art=ZX...     NaN
# 2      https://cafe.naver.com/dnfdot/12668?art=ZXh0ZX...     NaN
# 3      https://cafe.naver.com/dgmom365/5227805?art=ZX...     NaN
# 4      https://cafe.naver.com/ganada0811/46463?art=ZX...     NaN
# ...                                                  ...     ...
# 55039  https://cafe.naver.com/gagebuband/429?art=ZXh0...     NaN
# 55040  https://cafe.naver.com/tongkn/4321?art=ZXh0ZXJ...     NaN
# 55041  https://cafe.naver.com/greenb0k6k/25699?art=ZX...     NaN
# 55042  https://cafe.naver.com/mamtalks/3013?art=ZXh0Z...     NaN
# 55043  https://cafe.naver.com/jsseo43/18879?art=ZXh0Z...     NaN
#
# [55012 rows x 9 columns]

# %% [markdown]
# ## 제목, 본문, 댓글을 하나로 통합

# %%
# 혹시 리뷰 중에 Null 값을 가진 샘플이 있는지 확인
print(df3.isnull().sum())
# Out:
# Unnamed: 0        0
# date              0
# keyword           0
# title             0
# contents         20
# comments          0
# site              0
# url               0
# content       55012
# dtype: int64

# %%
#content 열 없음 빼기
df3 = df3.drop('content', axis=1)

# %%
df3.shape
# 혹시 리뷰 중에 Null 값을 가진 샘플이 있는지 확인
print(df3.isnull().sum())
# Out:
# Unnamed: 0    0
# date          0
# keyword       0
# title         0
# contents      0
# comments      0
# site          0
# url           0
# dtype: int64

# %%
df3 = df3.dropna()
df3.shape
# Out:
# (54992, 8)

# %%
# 위에서 Null값이 나오면 공백으로 수정 (Null 값 포함해서 doc로 합치면 Null값으로 반환됨)
df3['contents'] = df3['contents'].fillna('')
print(df3.isnull().values.any()) # 제거되었는지 확인
# Out:
# False

# %%
df3.loc[:,'review'] = df3['title'] + ' ' + df3['contents'] + ' ' + df3['comments']
df3['review']
df3 = df3.reset_index(drop=True)

# %%
df_doc = df3.review
df_doc
# Out:
# 0        꽃가루 알러지 없는 부모님은 모르는 아이의 꽃가루 알러지... 시작되었습니다. (이...
# 1        꽃가루 알러지 있는 자녀 두신 부모님 보세요~ 네이버 꽃가루 지수 검색하면 꽃가루 ...
# 2        부산 유아 아토피, 한의학에서 바라보는 원인과 증상에 대하여 안녕하세요. 가려움에 ...
# 3        꽃가루 알러지 있으신 자녀 키우시는 분들 보세요~ 학기초만 되면 (보통 중간고사 기...
# 4        어린이 운동회에 참여하다 이제 겨울이 가고 봄이 찾아왔다. 봄이란 무엇인가?봄은 본...
#                                ...
# 54987     함께 못 사는 나라로 가고 있다 ~165페이지~끝  세상에서 옷장정리가가장 어려운...
# 54988     [커버스토리] 나는 단순하게 살기로 했다…미니멀 라이프 실천하는 그들  첨부파일 ...
# 54989     7. 꿈깨라 이년아 79 최서방 첩  우선 진짜 감사하다는 말.꼭 하고 싶습니다....
# 54990     (강서양천점) 현숙 이모님 감사합니다~   S#1 1950년 6월 23일 금요일(...
# 54991     인도네시아 /나무위키 (2/2)   S#1 서울 석구집, 전경 (밤)S#2 석구집...
# Name: review, Length: 54992, dtype: object

# %% [markdown]
# ## 반복되는 문장 삭제

# %%
# 따옴표 안에 삭제할 문구를 복사해서 붙여넣기 해준다.
df_doc = df_doc.str.replace("경상도 3pl 전문 라온아토입니다","")
df_doc = df_doc.str.replace("(원스톱 사업자등록) 월 18000원 비상주 서비스 바로 가입! 바로 임대차계약서 발급까지!","")
df_doc = df_doc.str.replace("출석합니다","")
df_doc = df_doc.str.replace("출첵합니다.","")
df_doc = df_doc.str.replace("가입인사","")
df_doc = df_doc.str.replace("잘부탁드립니다.","")
df_doc = df_doc.str.replace("감사합니다.","")
df_doc = df_doc.str.replace("부탁드립니다","")
df_doc = df_doc.str.replace("연락부탁드립니다.","")

df_doc = df_doc.str.replace("긴글+ 사진폭탄 주의","")
df_doc = df_doc.str.replace("질문 있습니당.","")
df_doc = df_doc.str.replace("★","")

df_doc = df_doc.str.replace("댓글 없음","")
df_doc = df_doc.str.replace("< 아래 양식을 지켜주셔야 글 삭제와 회원강등이 안되니 꼭 지켜서 작성해주세요 >","")
df_doc = df_doc.str.replace("양식을 무시할 경우 운영규칙상 삭제 및 활동정지 될수 있으니 참고부탁드립니다.","")
df_doc = df_doc.str.replace("인스타 양도글은 인터넷 진흥원에서 안된다고 경고를 해서 카페에서 금지하고 있습니다","")
df_doc = df_doc.str.replace("카페활동 없이 양도글만 남길 경우 사이트의 자세한 설명없이 개인연락 유도글은 제재하고 있습니다","")

df_doc = df_doc.str.replace("안녕하세요","")
df_doc = df_doc.str.replace("안녕하세요!","")
df_doc = df_doc.str.replace("안녕하세요.","")

df_doc = df_doc.str.replace("쪽지드렸습니다", "")
df_doc = df_doc.str.replace("챗드릴게요","")
df_doc = df_doc.str.replace("쪽지주세요","")
df_doc = df_doc.str.replace("쪽지드릴게요","")
df_doc = df_doc.str.replace("쪽지 드렸어요","")
df_doc = df_doc.str.replace("댓글이나 쪽지로 주세요","")

df_doc = df_doc.str.replace(" 카페 활동 공지 사항 필독 <-- 가입인사 글쓰기 후 확인하시고 활동하셔야 합니다","")
df_doc = df_doc.str.replace("◆◆◆◆◆◆    진단평가와 관련된 내용만 올려주세요 그 외의 글은 삭제 및 활동제재합니다 ◆◆◆◆◆","")
df_doc = df_doc.str.replace("구합니다.","")
df_doc = df_doc.str.replace("등업조건:가입인사,출석 게시판 각 1개씩 글을 쓰고 각 게시판에 10씩 댓글을 달면 자동등업","")
df_doc = df_doc.str.replace("판매합니다","")
df_doc = df_doc.str.replace("수고하세요.","")
df_doc = df_doc.str.replace("쪽지 부탁드려요.","")
df_doc = df_doc.str.replace("소통해요.","")
df_doc = df_doc.str.replace("소통하고싶어요.","")
df_doc = df_doc.str.replace("해드리겠습니다.","")
df_doc = df_doc.str.replace("진행해드리겠습니다.","")
df_doc = df_doc.str.replace("말씀드리겠습니다.","")
df_doc = df_doc.str.replace("모집중에있습니다.","")
df_doc = df_doc.str.replace("양도합니다.","")
df_doc = df_doc.str.replace("전매합니다.","")
df_doc = df_doc.str.replace("확인합니다","")

df_doc = df_doc.str.replace("댓글없음.","")
df_doc = df_doc.str.replace("나눔후기\)","")
df_doc = df_doc.str.replace("\[체험후기\]","")

# %%
df_doc
# Out:
# 0        꽃가루 알러지 없는 부모님은 모르는 아이의 꽃가루 알러지... 시작되었습니다. (이...
# 1        꽃가루 알러지 있는 자녀 두신 부모님 보세요~ 네이버 꽃가루 지수 검색하면 꽃가루 ...
# 2        부산 유아 아토피, 한의학에서 바라보는 원인과 증상에 대하여 . 가려움에 밤잠 못 ...
# 3        꽃가루 알러지 있으신 자녀 키우시는 분들 보세요~ 학기초만 되면 (보통 중간고사 기...
# 4        어린이 운동회에 참여하다 이제 겨울이 가고 봄이 찾아왔다. 봄이란 무엇인가?봄은 본...
#                                ...
# 54987     함께 못 사는 나라로 가고 있다 ~165페이지~끝  세상에서 옷장정리가가장 어려운...
# 54988     [커버스토리] 나는 단순하게 살기로 했다…미니멀 라이프 실천하는 그들  첨부파일 ...
# 54989     7. 꿈깨라 이년아 79 최서방 첩  우선 진짜 감사하다는 말.꼭 하고 싶습니다....
# 54990     (강서양천점) 현숙 이모님 감사합니다~   S#1 1950년 6월 23일 금요일(...
# 54991     인도네시아 /나무위키 (2/2)   S#1 서울 석구집, 전경 (밤)S#2 석구집...
# Name: review, Length: 54992, dtype: object

# %% [markdown]
# ## 텍스트 전처리

# %%
df_doc = df_doc.str.replace("[0-9]+갤","개월", regex = True) # ex.8갤->개월(맞춤법 검사 시 교정 안 됌)
df_doc = df_doc.str.replace("[^가-힣a-zA-z ]"," ", regex=True) # 한글,영어만 남기고 특수문자, 숫자 삭제
df_doc = df_doc.str.replace("\s+", " ", regex = True) # white space 제거
df_doc = df_doc.str.replace(r"\\n", " ", regex=True)
df_doc = df_doc.str.replace(r'[^\w\s가-힣]', '', regex=True)

df_doc = df_doc.str.strip()

# %%
df_doc
# Out:
# 0        꽃가루 알러지 없는 부모님은 모르는 아이의 꽃가루 알러지 시작되었습니다 이 글을 봄...
# 1        꽃가루 알러지 있는 자녀 두신 부모님 보세요 네이버 꽃가루 지수 검색하면 꽃가루 소...
# 2        부산 유아 아토피 한의학에서 바라보는 원인과 증상에 대하여 가려움에 밤잠 못 이루는...
# 3        꽃가루 알러지 있으신 자녀 키우시는 분들 보세요 학기초만 되면 보통 중간고사 기간부...
# 4        어린이 운동회에 참여하다 이제 겨울이 가고 봄이 찾아왔다 봄이란 무엇인가 봄은 본디...
#                                ...
# 54987    함께 못 사는 나라로 가고 있다 페이지 끝 세상에서 옷장정리가가장 어려운 것 같아요...
# 54988    커버스토리 나는 단순하게 살기로 했다 미니멀 라이프 실천하는 그들 첨부파일 산책_ ...
# 54989    꿈깨라 이년아 최서방 첩 우선 진짜 감사하다는 말 꼭 하고 싶습니다 솔직히 엄청 혼...
# 54990    강서양천점 현숙 이모님 감사합니다 S 년 월 일 금요일 저녁 시 서울 석구집 년 월...
# 54991    인도네시아 나무위키 S 서울 석구집 전경 밤 S 석구집 방안 밤 S 기차 안 낮 사...
# Name: review, Length: 54992, dtype: object

# %%
doc = pd.DataFrame(df_doc)
doc
# Out:
#                                                   review
# 0      꽃가루 알러지 없는 부모님은 모르는 아이의 꽃가루 알러지 시작되었습니다 이 글을 봄...
# 1      꽃가루 알러지 있는 자녀 두신 부모님 보세요 네이버 꽃가루 지수 검색하면 꽃가루 소...
# 2      부산 유아 아토피 한의학에서 바라보는 원인과 증상에 대하여 가려움에 밤잠 못 이루는...
# 3      꽃가루 알러지 있으신 자녀 키우시는 분들 보세요 학기초만 되면 보통 중간고사 기간부...
# 4      어린이 운동회에 참여하다 이제 겨울이 가고 봄이 찾아왔다 봄이란 무엇인가 봄은 본디...
# ...                                                  ...
# 54987  함께 못 사는 나라로 가고 있다 페이지 끝 세상에서 옷장정리가가장 어려운 것 같아요...
# 54988  커버스토리 나는 단순하게 살기로 했다 미니멀 라이프 실천하는 그들 첨부파일 산책_ ...
# 54989  꿈깨라 이년아 최서방 첩 우선 진짜 감사하다는 말 꼭 하고 싶습니다 솔직히 엄청 혼...
# 54990  강서양천점 현숙 이모님 감사합니다 S 년 월 일 금요일 저녁 시 서울 석구집 년 월...
# 54991  인도네시아 나무위키 S 서울 석구집 전경 밤 S 석구집 방안 밤 S 기차 안 낮 사...
#
# [54992 rows x 1 columns]

# %%
doc['review'] = doc['review'].str.replace(r'\[이미지[^\]]*\]', '', regex=True)
doc['review'] = doc['review'].str.replace(r'\s+', ' ', regex=True)
# 결과 확인
doc
# Out:
#                                                   review
# 0      꽃가루 알러지 없는 부모님은 모르는 아이의 꽃가루 알러지 시작되었습니다 이 글을 봄...
# 1      꽃가루 알러지 있는 자녀 두신 부모님 보세요 네이버 꽃가루 지수 검색하면 꽃가루 소...
# 2      부산 유아 아토피 한의학에서 바라보는 원인과 증상에 대하여 가려움에 밤잠 못 이루는...
# 3      꽃가루 알러지 있으신 자녀 키우시는 분들 보세요 학기초만 되면 보통 중간고사 기간부...
# 4      어린이 운동회에 참여하다 이제 겨울이 가고 봄이 찾아왔다 봄이란 무엇인가 봄은 본디...
# ...                                                  ...
# 54987  함께 못 사는 나라로 가고 있다 페이지 끝 세상에서 옷장정리가가장 어려운 것 같아요...
# 54988  커버스토리 나는 단순하게 살기로 했다 미니멀 라이프 실천하는 그들 첨부파일 산책_ ...
# 54989  꿈깨라 이년아 최서방 첩 우선 진짜 감사하다는 말 꼭 하고 싶습니다 솔직히 엄청 혼...
# 54990  강서양천점 현숙 이모님 감사합니다 S 년 월 일 금요일 저녁 시 서울 석구집 년 월...
# 54991  인도네시아 나무위키 S 서울 석구집 전경 밤 S 석구집 방안 밤 S 기차 안 낮 사...
#
# [54992 rows x 1 columns]

# %%
doc["data"] = df3["date"]

# %%
doc
# Out:
#                                                   review        data
# 0      꽃가루 알러지 없는 부모님은 모르는 아이의 꽃가루 알러지 시작되었습니다 이 글을 봄...  2022-04-10
# 1      꽃가루 알러지 있는 자녀 두신 부모님 보세요 네이버 꽃가루 지수 검색하면 꽃가루 소...  2021-05-09
# 2      부산 유아 아토피 한의학에서 바라보는 원인과 증상에 대하여 가려움에 밤잠 못 이루는...  2025-04-14
# 3      꽃가루 알러지 있으신 자녀 키우시는 분들 보세요 학기초만 되면 보통 중간고사 기간부...  2021-04-18
# 4      어린이 운동회에 참여하다 이제 겨울이 가고 봄이 찾아왔다 봄이란 무엇인가 봄은 본디...  2024-04-19
# ...                                                  ...         ...
# 54987  함께 못 사는 나라로 가고 있다 페이지 끝 세상에서 옷장정리가가장 어려운 것 같아요...  2021-07-04
# 54988  커버스토리 나는 단순하게 살기로 했다 미니멀 라이프 실천하는 그들 첨부파일 산책_ ...  2021-10-24
# 54989  꿈깨라 이년아 최서방 첩 우선 진짜 감사하다는 말 꼭 하고 싶습니다 솔직히 엄청 혼...  2020-12-11
# 54990  강서양천점 현숙 이모님 감사합니다 S 년 월 일 금요일 저녁 시 서울 석구집 년 월...  2020-12-04
# 54991  인도네시아 나무위키 S 서울 석구집 전경 밤 S 석구집 방안 밤 S 기차 안 낮 사...  2022-05-17
#
# [54992 rows x 2 columns]

# %%
doc.to_csv("/content/drive/MyDrive/DataSet/네이버포털_전처리완료.csv", index=False, encoding='utf-8-sig')
